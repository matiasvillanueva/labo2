# %% [markdown]
# # Notebook de prueba
#
# Este notebook verifica que el entorno conda `labo2` funciona correctamente.

# %%
import sys
import numpy as np
import pandas as pd

print(f"Python: {sys.version}")
print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")

# %%
data = pd.DataFrame({
    "x": np.arange(5),
    "y": np.arange(5) ** 2
})

data

# %%
print("Todo OK: Jupyter y las librerias estan funcionando.")
